# %% [markdown]
# ### 5 day weather forecast
# https://openweathermap.org/forecast5
#
#
# Product concept
# 5 day forecast is available at any location on the globe. It includes weather forecast data with 3-hour step. Forecast is available in JSON or XML format.
#
# Call 5 day / 3 hour forecast data
# How to make an API call
# You can search weather forecast for 5 days with data every 3 hours by geographic coordinates. All weather data can be obtained in JSON and XML formats.
#
# API call
#
# api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API key}
#
# Parameters
# - lat	required	Latitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our Geocoding API
# - lon	required	Longitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our Geocoding API
# - appid	required	Your unique API key (you can always find it on your account page under the "API key" tab)
# - units	optional	Units of measurement. standard, metric and imperial units are available. If you do not use the units parameter, standard units will be applied by default.
# - mode	optional	Response format. JSON format is used by default. To get data in XML format use mode=xml.
# - cnt	optional	A number of timestamps, which will be returned in the API response.
# - lang	optional	You can use the lang parameter to get the output in your language.

# %% [markdown]
# ### 1.1 Import the required libraries

# %%
import pandas as pd
import requests
from safe import API_key #user API Key

# %% [markdown]
# ### 1.2 Accessing the data

# %%
#### Use this if want to use latitude and longitude

# latitude = 52.5200	
# longitude = 13.405
# API_key = API_key
# temp_unit = 'metric' # Display temp in Celcius
# weather = requests.get(f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units={temp_unit}")

# weather = weather.json()
# weather

# %%
##### You can search weather forecast for 5 days with data every 3 hours by city name.
city_name = 'Berlin'
API_key = API_key  #User API Key
temp_unit = 'metric' # Display temp in Celcius

weather = requests.get(f"https://api.openweathermap.org/data/2.5/forecast?q={city_name}&appid={API_key}&units={temp_unit}")

weather = weather.json()
weather
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1733076000,
#    'main': {'temp': 1.03,
#     'feels_like': -2.45,
#     'temp_min': 1.03,
#     'temp_max': 2.48,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1016,
#     'humidity': 85,
#     'temp_kf': -1.45},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.23, 'deg': 166, 'gust': 9.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-01 18:00:00'},
#   {'dt': 1733086800,
#    'main': {'temp': 1.42,
#     'feels_like': -2.42,
#     'temp_min': 1.42,
#     'temp_max': 2.2,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1015,
#     'humidity': 79,
#     'temp_kf': -0.78},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.83, 'deg': 183, 'gust': 11.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-01 21:00:00'},
#   {'dt': 1733097600,
#    'main': {'temp': 1.49,
#     'feels_like': -2.31,
#     'temp_min': 1.49,
#     'temp_max': 1.72,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1013,
#     'humidity': 73,
#     'temp_kf': -0.23},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 3.79, 'deg': 189, 'gust': 12.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-02 00:00:00'},
#   {'dt': 1733108400,
#    'main': {'temp': 1.39,
#     'feels_like': -2.11,
#     'temp_min': 1.39,
#     'temp_max': 1.39,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1012,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 3.35, 'deg': 198, 'gust': 9.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-02 03:00:00'},
#   {'dt': 1733119200,
#    'main': {'temp': 1.42,
#     'feels_like': -1.63,
#     'temp_min': 1.42,
#     'temp_max': 1.42,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1011,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 2.81, 'deg': 194, 'gust': 6.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-02 06:00:00'},
#   {'dt': 1733130000,
#    'main': {'temp': 3.74,
#     'feels_like': 1.2,
#     'temp_min': 3.74,
#     'temp_max': 3.74,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1011,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.74, 'deg': 196, 'gust': 6.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-02 09:00:00'},
#   {'dt': 1733140800,
#    'main': {'temp': 6.28,
#     'feels_like': 3.93,
#     'temp_min': 6.28,
#     'temp_max': 6.28,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.16, 'deg': 194, 'gust': 7.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-02 12:00:00'},
#   {'dt': 1733151600,
#    'main': {'temp': 5.65,
#     'feels_like': 3.15,
#     'temp_min': 5.65,
#     'temp_max': 5.65,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 3.2, 'deg': 190, 'gust': 8.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-02 15:00:00'},
#   {'dt': 1733162400,
#    'main': {'temp': 5.01,
#     'feels_like': 2.41,
#     'temp_min': 5.01,
#     'temp_max': 5.01,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 3.15, 'deg': 199, 'gust': 9.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-02 18:00:00'},
#   {'dt': 1733173200,
#    'main': {'temp': 5.58,
#     'feels_like': 3.58,
#     'temp_min': 5.58,
#     'temp_max': 5.58,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.51, 'deg': 201, 'gust': 7.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-02 21:00:00'},
#   {'dt': 1733184000,
#    'main': {'temp': 5.64,
#     'feels_like': 3.54,
#     'temp_min': 5.64,
#     'temp_max': 5.64,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.64, 'deg': 211, 'gust': 7.47},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.51},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-03 00:00:00'},
#   {'dt': 1733194800,
#    'main': {'temp': 5.48,
#     'feels_like': 3.35,
#     'temp_min': 5.48,
#     'temp_max': 5.48,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.65, 'deg': 233, 'gust': 9.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-03 03:00:00'},
#   {'dt': 1733205600,
#    'main': {'temp': 4.82,
#     'feels_like': 2.43,
#     'temp_min': 4.82,
#     'temp_max': 4.82,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 2.82, 'deg': 237, 'gust': 8.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-03 06:00:00'},
#   {'dt': 1733216400,
#    'main': {'temp': 5.62,
#     'feels_like': 2.99,
#     'temp_min': 5.62,
#     'temp_max': 5.62,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.39, 'deg': 258, 'gust': 8.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-03 09:00:00'},
#   {'dt': 1733227200,
#    'main': {'temp': 6.29,
#     'feels_like': 4.71,
#     'temp_min': 6.29,
#     'temp_max': 6.29,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1011,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.17, 'deg': 244, 'gust': 6.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-03 12:00:00'},
#   {'dt': 1733238000,
#    'main': {'temp': 5.83,
#     'feels_like': 4.69,
#     'temp_min': 5.83,
#     'temp_max': 5.83,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1012,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.67, 'deg': 257, 'gust': 4.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-03 15:00:00'},
#   {'dt': 1733248800,
#    'main': {'temp': 5.32,
#     'feels_like': 3.39,
#     'temp_min': 5.32,
#     'temp_max': 5.32,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1014,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.37, 'deg': 308, 'gust': 4.39},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.16},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-03 18:00:00'},
#   {'dt': 1733259600,
#    'main': {'temp': 4.86,
#     'feels_like': 3.5,
#     'temp_min': 4.86,
#     'temp_max': 4.86,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1015,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.73, 'deg': 312, 'gust': 3.43},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-03 21:00:00'},
#   {'dt': 1733270400,
#    'main': {'temp': 4.43,
#     'feels_like': 3.08,
#     'temp_min': 4.43,
#     'temp_max': 4.43,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1016,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.67, 'deg': 245, 'gust': 2.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-04 00:00:00'},
#   {'dt': 1733281200,
#    'main': {'temp': 3.88,
#     'feels_like': 3.88,
#     'temp_min': 3.88,
#     'temp_max': 3.88,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1017,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.21, 'deg': 258, 'gust': 1.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-04 03:00:00'},
#   {'dt': 1733292000,
#    'main': {'temp': 3.4,
#     'feels_like': 1.61,
#     'temp_min': 3.4,
#     'temp_max': 3.4,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1018,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.91, 'deg': 254, 'gust': 3.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-04 06:00:00'},
#   {'dt': 1733302800,
#    'main': {'temp': 3.56,
#     'feels_like': 2.45,
#     'temp_min': 3.56,
#     'temp_max': 3.56,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1019,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.4, 'deg': 275, 'gust': 2.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-04 09:00:00'},
#   {'dt': 1733313600,
#    'main': {'temp': 4.73,
#     'feels_like': 4.73,
#     'temp_min': 4.73,
#     'temp_max': 4.73,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1020,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 0.93, 'deg': 267, 'gust': 1.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-04 12:00:00'},
#   {'dt': 1733324400,
#    'main': {'temp': 4.27,
#     'feels_like': 3.11,
#     'temp_min': 4.27,
#     'temp_max': 4.27,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1021,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 1.5, 'deg': 295, 'gust': 1.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-04 15:00:00'},
#   {'dt': 1733335200,
#    'main': {'temp': 4,
#     'feels_like': 2.02,
#     'temp_min': 4,
#     'temp_max': 4,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 2.18, 'deg': 289, 'gust': 2.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-04 18:00:00'},
#   {'dt': 1733346000,
#    'main': {'temp': 3.43,
#     'feels_like': 2.13,
#     'temp_min': 3.43,
#     'temp_max': 3.43,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 1.52, 'deg': 285, 'gust': 2.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-04 21:00:00'},
#   {'dt': 1733356800,
#    'main': {'temp': 1.73,
#     'feels_like': -0.08,
#     'temp_min': 1.73,
#     'temp_max': 1.73,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 1.71, 'deg': 258, 'gust': 2.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-05 00:00:00'},
#   {'dt': 1733367600,
#    'main': {'temp': 1.01,
#     'feels_like': -1.32,
#     'temp_min': 1.01,
#     'temp_max': 1.01,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 2.03, 'deg': 267, 'gust': 4.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-05 03:00:00'},
#   {'dt': 1733378400,
#    'main': {'temp': 0.29,
#     'feels_like': -2.08,
#     'temp_min': 0.29,
#     'temp_max': 0.29,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 1.97, 'deg': 258, 'gust': 4.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-05 06:00:00'},
#   {'dt': 1733389200,
#    'main': {'temp': 1.24,
#     'feels_like': -0.7,
#     'temp_min': 1.24,
#     'temp_max': 1.24,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 1.75, 'deg': 224, 'gust': 3.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-05 09:00:00'},
#   {'dt': 1733400000,
#    'main': {'temp': 3.4,
#     'feels_like': 1.26,
#     'temp_min': 3.4,
#     'temp_max': 3.4,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 2.23, 'deg': 205, 'gust': 3.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-05 12:00:00'},
#   {'dt': 1733410800,
#    'main': {'temp': 2.47,
#     'feels_like': -0.3,
#     'temp_min': 2.47,
#     'temp_max': 2.47,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1021,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.72, 'deg': 170, 'gust': 6.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-05 15:00:00'},
#   {'dt': 1733421600,
#    'main': {'temp': 1.34,
#     'feels_like': -2.42,
#     'temp_min': 1.34,
#     'temp_max': 1.34,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1019,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.68, 'deg': 167, 'gust': 9.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-05 18:00:00'},
#   {'dt': 1733432400,
#    'main': {'temp': 0.95,
#     'feels_like': -3.83,
#     'temp_min': 0.95,
#     'temp_max': 0.95,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 5.19, 'deg': 163, 'gust': 12.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-05 21:00:00'},
#   {'dt': 1733443200,
#    'main': {'temp': 1.23,
#     'feels_like': -3.72,
#     'temp_min': 1.23,
#     'temp_max': 1.23,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1011,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 5.65, 'deg': 166, 'gust': 13.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-06 00:00:00'},
#   {'dt': 1733454000,
#    'main': {'temp': 0.27,
#     'feels_like': -4.97,
#     'temp_min': 0.27,
#     'temp_max': 0.27,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.72, 'deg': 172, 'gust': 14.49},
#    'visibility': 71,
#    'pop': 1,
#    'snow': {'3h': 4.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-06 03:00:00'},
#   {'dt': 1733464800,
#    'main': {'temp': 0.96,
#     'feels_like': -3.33,
#     'temp_min': 0.96,
#     'temp_max': 0.96,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.35, 'deg': 169, 'gust': 10.7},
#    'pop': 1,
#    'rain': {'3h': 3.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-06 06:00:00'},
#   {'dt': 1733475600,
#    'main': {'temp': 5.59,
#     'feels_like': 1,
#     'temp_min': 5.59,
#     'temp_max': 5.59,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1007,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.8, 'deg': 294, 'gust': 14.88},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.57},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-06 09:00:00'},
#   {'dt': 1733486400,
#    'main': {'temp': 5.99,
#     'feels_like': 1.92,
#     'temp_min': 5.99,
#     'temp_max': 5.99,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1011,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.61, 'deg': 279, 'gust': 12.85},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.46},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-12-06 12:00:00'},
#   {'dt': 1733497200,
#    'main': {'temp': 5.55,
#     'feels_like': 1.71,
#     'temp_min': 5.55,
#     'temp_max': 5.55,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 5.71, 'deg': 277, 'gust': 11.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-12-06 15:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 3600,
#   'sunrise': 1733036105,
#   'sunset': 1733064979}}

# %% [markdown]
# #### Parameters to extract from JSON response :
# JSON format API response fields
# - cnt A number of timestamps returned in the API response
# - list
#     - list.main
#         - list.main.temp Temperature. Unit Default: Kelvin, Metric: Celsius, Imperial: Fahrenheit
#         - list.main.feels_like This temperature parameter accounts for the human perception of weather.
#         - list.main.humidity Humidity, % #Expressed in percentage
#
#     - list.weather
#         - list.weather.description Weather condition within the group.
#
#     - list.clouds
#         - list.clouds.all Cloudiness, %
#
#     - list.wind
#         - list.wind.speed Wind speed. Unit Default: meter/sec, Metric: meter/sec, Imperial: miles/hour
#
#     - list.pop Probability of precipitation. The values of the parameter vary between 0 and 1, where 0 is equal to 0%, 1 is equal to 100% #indicate rain probability
#
#
#     - list.sys
#         - list.sys.pod Part of the day (n - night, d - day)
#
#     - list.dt_txt Time of data forecasted, ISO, UTC
#
#
# **Not decided about below parameter**
# - list.rain
#         - list.rain.3h Rain volume for last 3 hours, mm. Please note that only mm as units of measurement are available for this parameter
#
#     - list.snow
#         - list.snow.3h Snow volume for last 3 hours. Please note that only mm as units of measurement are available for this parameter
#
# city
# city.id City ID. Please note that built-in geocoder functionality has been deprecated. Learn more here
# city.name City name. Please note that built-in geocoder functionality has been deprecated. Learn more here
# city.coord
# city.coord.lat Geo location, latitude
# city.coord.lon Geo location, longitude
# city.country Country code (GB, JP etc.). Please note that built-in geocoder functionality has been deprecated. Learn more here
# city.population City population

# %% [markdown]
# ### 1.3 Accessing only required values

# %%
weather['list'][0]['main']['feels_like'] # actual feels like temperature in degree celcius
# Out:
# -2.45

# %%
weather['list'][0]['weather'][0]['description'] #Weather_condition within the group
# Out:
# 'clear sky'

# %%
weather['list'][0]['clouds']['all'] #Cloudiness in percentage
# Out:
# 0

# %%
weather['list'][0]['wind']['speed'] #Wind_speed in meter/sec
# Out:
# 3.23

# %%
weather['list'][0]['pop'] #pop-Probability_of_Perception values between 0 & 1. Indicated probabiltiy of rain
# Out:
# 0

# %%
weather['list'][0]['sys']['pod'] #Part of the night (n-night, d-day)
# Out:
# 'n'

# %%
weather['list'][0]['dt_txt'] #Time of data forecasted, ISO, UTC
# Out:
# '2024-12-01 18:00:00'

# %% [markdown]
# ### 1.4 Creating a for loop to access all the data

# %%
#store all 'values' belong to key 'list' (key:value)
date_time = []
temperature = [] 
weather_condition = []
cloudiness = []
wind_speed = []
pop = []
pod = []

for count in range(weather['cnt']): #cnt - A number of timestamps returned in the API response

    all_data = weather['list'][count]

    #Time of data forecasted, ISO, UTC
    date_time.append(all_data['dt_txt']) 

    # actual feels like temperature in degree celcius
    temperature.append(all_data['main']['feels_like'])

    #weather_condition within the group
    weather_condition.append(all_data['weather'][0]['description']) 

    #cloudiness in percentage
    cloudiness.append(all_data['clouds']['all'])

    #wind_speed in meter/sec
    wind_speed.append(all_data['wind']['speed']) 

    #pop-Probability_of_Perception values between 0 & 1. Indicated probabiltiy of rain
    pop.append(all_data['pop']) 

    #Part of the day (n-night, d-day)
    pod.append(all_data['sys']['pod'])

# %% [markdown]
# ### 1.4 Creating a function
# - use only one list instead of severals
# - produce output as a dataframe

# %%
def WeatherData(city_name, API_key, temp_unit):
    
    #store all 'values' belong to key 'list' (key:value)
    weather_data = []

    for name in city_name:

        weather = requests.get(f"https://api.openweathermap.org/data/2.5/forecast?q={name}&appid={API_key}&units={temp_unit}")

        weather = weather.json()

        for count in range(weather['cnt']): #cnt - A number of timestamps returned in the API response

            all_data = weather['list'][count]

            #Time of data forecasted, ISO, UTC
            date_time = all_data['dt_txt']

            # actual feels like temperature in degree celcius
            temperature = all_data['main']['feels_like']

            #weather_condition within the group
            weather_condition = all_data['weather'][0]['description']

            #cloudiness in percentage
            cloudiness = all_data['clouds']['all']

            #wind_speed in meter/sec
            wind_speed = all_data['wind']['speed']

            #pop-Probability_of_Perception values between 0 & 1. Indicated probabiltiy of rain
            pop = all_data['pop']

            #Part of the day (n-night, d-day)
            pod = all_data['sys']['pod']

            weather_data.append({#"city" : name,
                                "forecast_time" : date_time,
                                "feels_like (℃)" : temperature,
                                "weather_condition" : weather_condition,
                                "cloudiness (%)" : cloudiness,
                                "wind_speed (M/sec)" : wind_speed,
                                "rain_probability (%)" : pop * 100,
                                "part_of_day" : pod
                                })
    return pd.DataFrame(weather_data)

# %%
##### You can search weather forecast for 5 days with data every 3 hours by city name.
city_name = ['Berlin'] #['Berlin', 'Munich']
API_key = API_key #Use API Key
temp_unit = 'metric' # Display temp in Celcius

WeatherData(city_name, API_key, temp_unit)
# Out:
#           forecast_time  feels_like (℃) weather_condition  cloudiness (%)  \
# 0   2024-12-01 21:00:00           -3.51         clear sky               0
# 1   2024-12-02 00:00:00           -3.00         clear sky               2
# 2   2024-12-02 03:00:00           -2.46         clear sky               7
# 3   2024-12-02 06:00:00           -1.63  scattered clouds              39
# 4   2024-12-02 09:00:00            1.20   overcast clouds             100
# 5   2024-12-02 12:00:00            3.93   overcast clouds             100
# 6   2024-12-02 15:00:00            3.15     broken clouds              57
# 7   2024-12-02 18:00:00            2.41     broken clouds              67
# 8   2024-12-02 21:00:00            3.58   overcast clouds              99
# 9   2024-12-03 00:00:00            3.54        light rain             100
# 10  2024-12-03 03:00:00            3.35   overcast clouds             100
# 11  2024-12-03 06:00:00            2.43   overcast clouds              92
# 12  2024-12-03 09:00:00            2.99   overcast clouds              99
# 13  2024-12-03 12:00:00            4.71   overcast clouds              94
# 14  2024-12-03 15:00:00            4.69   overcast clouds             100
# 15  2024-12-03 18:00:00            3.39        light rain             100
# 16  2024-12-03 21:00:00            3.50        light rain             100
# 17  2024-12-04 00:00:00            3.08   overcast clouds             100
# 18  2024-12-04 03:00:00            3.88   overcast clouds             100
# 19  2024-12-04 06:00:00            1.61   overcast clouds              99
# 20  2024-12-04 09:00:00            2.45   overcast clouds             100
# 21  2024-12-04 12:00:00            4.73   overcast clouds              95
# 22  2024-12-04 15:00:00            3.11     broken clouds              67
# 23  2024-12-04 18:00:00            2.02     broken clouds              83
# 24  2024-12-04 21:00:00            2.13   overcast clouds              90
# 25  2024-12-05 00:00:00           -0.08     broken clouds              52
# 26  2024-12-05 03:00:00           -1.32         clear sky               9
# 27  2024-12-05 06:00:00           -2.08         clear sky              10
# 28  2024-12-05 09:00:00           -0.70         clear sky               9
# 29  2024-12-05 12:00:00            1.26         clear sky               9
# 30  2024-12-05 15:00:00           -0.30         clear sky               8
# 31  2024-12-05 18:00:00           -2.42        few clouds              18
# 32  2024-12-05 21:00:00           -3.83        few clouds              18
# 33  2024-12-06 00:00:00           -3.72     broken clouds              59
# 34  2024-12-06 03:00:00           -4.97              snow             100
# 35  2024-12-06 06:00:00           -3.33     moderate rain             100
# 36  2024-12-06 09:00:00            1.00        light rain             100
# 37  2024-12-06 12:00:00            1.92        light rain             100
# 38  2024-12-06 15:00:00            1.71   overcast clouds              91
# 39  2024-12-06 18:00:00            2.79   overcast clouds              96
#
#     wind_speed (M/sec)  rain_probability (%) part_of_day
# 0                 3.83                   0.0           n
# 1                 3.79                   0.0           n
# 2                 3.35                   0.0           n
# 3                 2.81                   0.0           n
# 4                 2.74                   0.0           d
# 5                 3.16                   0.0           d
# 6                 3.20                   0.0           n
# 7                 3.15                   0.0           n
# 8                 2.51                   0.0           n
# 9                 2.64                  23.0           n
# 10                2.65                   0.0           n
# 11                2.82                   0.0           n
# 12                3.39                   0.0           d
# 13                2.17                   0.0           d
# 14                1.67                   0.0           n
# 15                2.37                  20.0           n
# 16                1.73                  20.0           n
# 17                1.67                   0.0           n
# 18                1.21                   0.0           n
# 19                1.91                   0.0           n
# 20                1.40                   0.0           d
# 21                0.93                   0.0           d
# 22                1.50                   0.0           n
# 23                2.18                   0.0           n
# 24                1.52                   0.0           n
# 25                1.71                   0.0           n
# 26                2.03                   0.0           n
# 27                1.97                   0.0           n
# 28                1.75                   0.0           d
# 29                2.23                   0.0           d
# 30                2.72                   0.0           n
# 31                3.68                   0.0           n
# 32                5.19                   0.0           n
# 33                5.65                   0.0           n
# 34                5.72                 100.0           n
# 35                4.35                 100.0           n
# 36                7.80                 100.0           d
# 37                6.61                 100.0           d
# 38                5.71                   0.0           n
# 39                3.87                   0.0           n

# %% [markdown]
# ### 1.5 Use geocoder API to get latitude and longitude and make function to fetch weather data

# %%
import pandas as pd
from datetime import datetime
from pytz import timezone

def fetch_weather_data(cities):
  # Let's ensure the timezone is our local timezone
  berlin_timezone = timezone('Europe/Berlin')
  API_key = API_key
  weather_items = []

  for city in cities:

    country = "DE"

    # Geocoder api to get the latitude and longitude
    # This information should be from your SQL table, but we don't have that here
    geo_url = (f"http://api.openweathermap.org/geo/1.0/direct?q={city},{country}&limit=5&appid={API_key}")
    geo_response = requests.get(geo_url)
    geo_json = geo_response.json()
    latitude = geo_json[0]["lat"]
    longitude = geo_json[0]["lon"]

    # weather api
    weather_url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")
    weather_response = requests.get(weather_url)
    weather_json = weather_response.json()

    # Added the time retrieved so we know when the forecast was made
    retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

    for item in weather_json["list"]:
        weather_item = {
            # Added the city name, so the information is clear when looking at multiple cities
            "city": city,
            "forecast_time": item.get("dt_txt", None),
            "temperature": item["main"].get("temp", None),
            "forecast": item["weather"][0].get("main", None),
            "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
            "wind_speed": item["wind"].get("speed", None),
            "data_retrieved_at": retrieval_time
        }

        weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)

  return weather_df

# %%
fetch_weather_data(["Berlin", "Hamburg", "Munich"])
