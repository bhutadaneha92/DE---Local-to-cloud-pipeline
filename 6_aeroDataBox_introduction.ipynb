# %% [markdown]
# So far we've learnt how to scrape the web, and how to make a request for information from an API. Some websites make APIs even easier. Check out [RapidAPI](https://rapidapi.com/) they take care of writing most of the code for you.
#
# We will use the [AeroDataBox API](https://rapidapi.com/aedbx-aedbx/api/aerodatabox/), which can retrieve all sorts of information about flights and airports. We will show you how to retrieve information about the airports, and then it's up to you to apply this, along with what you've already learnt this week, to **produce a function, which retrieves tomorrows flight information for the major airports in the cities you web scraped**.

# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
from pytz import timezone
from timezonefinder import TimezoneFinder

import sys
sys.path.append(r'E:\WBS DS\Python\GANS_e-scooter\safe_key.py') #give path to safe.py file where all password and keys are save in dictionary

from safe_key import safe_key

# %% [markdown]
# On the left hand side of the AeroDataBox API page, you'll see a list of options for information that you can retrieve:
# > - Flights API
# - Subsciption / PUSH API
# - Airport API
# - Aircraft API
# - Healthcheck & Status API
#
# 1. We want to select `Airport API`
#
# 2. Then within Airport API we want to select `Search airports by location`
#
# 3. Now in the middle third you'll want to enter the `latitude` and `longitude` of any city to test... we chose Berlin: latitude 52.31 longitude 13.24. Next we changed the `radiusKM` to only 50km. And finally set `withFlightInfoOnly` to true, so it will only return airports which have flight data (scheduled or live) available.
#
# 4. On the right hand third of the screen you should see a block of code that looks pretty unfamiliar. This is because by default the code is probably set to *(Node.js) Axios*. However, we have the power to change this to familiar python. Select the dropdown box at the top of the code and select `python > requests`.
#
# Now you can copy the code to your notebook and it should look a little something like the cell below:

# %%
url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

querystring = {"lat":"52.32","lon":"13.24","radiusKm":"50","limit":"16","withFlightInfoOnly":"true"}

headers = { "x-rapidapi-key": safe_key["x_rapidapi_key"],
           "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
			}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'searchBy': {'lat': 52.32, 'lon': 13.24},
#  'count': 1,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE',
#    'timeZone': 'Europe/Berlin'}]}

# %% [markdown]
# We can now turn this into a dataframe using `.json_normalize()`

# %%
pd.json_normalize(response.json()['items'])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889

# %% [markdown]
# Let's now use this for the latitude and longitude of multiple cities

# %%
def icao_airport_codes(latitudes, longitudes):

  #assert len(latitudes) == len(longitudes)

  list_for_df = []

  for index, value in enumerate(latitudes):

    url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

    querystring = {
      "lat": value, 
      "lon": longitudes[index], 
      "radiusKm":"100",
      "limit":"16", 
      "withFlightInfoOnly":"true" 
      }

    headers = { 
      "x-rapidapi-key": safe_key["x_rapidapi_key"],
      "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
			}

    response = requests.get(url, headers=headers, params=querystring)
    
    list_for_df.append(pd.json_normalize(response.json()['items']))

  return pd.concat(list_for_df, ignore_index=True)

# %%
# coordinates for Berlin, Paris, London (51.5072,-0.1275), Pune
latitudes = [52.5200, 48.8567,  18.5203]
longitudes = [13.4050, 2.3522, 73.8567]

airport_data_df = icao_airport_codes(latitudes, longitudes)
airport_data_df
# Out:
#    icao iata                                 name             shortName  \
# 0  EDDB  BER                   Berlin Brandenburg           Brandenburg
# 1  LFPB  LBG                    Paris -Le Bourget           -Le Bourget
# 2  LFPO  ORY                          Paris -Orly                 -Orly
# 3  LFPG  CDG              Paris Charles de Gaulle     Charles de Gaulle
# 4  LFOB  BVA  Beauvais/Tillé Paris Beauvais Tillé  Paris Beauvais Tillé
# 5  VAPO  PNQ                                Pune                   Pune
#
#   municipalityName countryCode       timeZone  location.lat  location.lon
# 0           Berlin          DE  Europe/Berlin      52.35139     13.493889
# 1            Paris          FR   Europe/Paris      48.96940      2.441390
# 2            Paris          FR   Europe/Paris      48.72530      2.359440
# 3            Paris          FR   Europe/Paris      49.01280      2.549999
# 4   Beauvais/Tillé          FR   Europe/Paris      49.45440      2.112780
# 5             Pune          IN   Asia/Kolkata      18.58210     73.919700

# %%
def icao_airport_codes(cities_info_from_sql): 
     
     list_for_df = []

     for row in cities_info_from_sql.itertuples(index=False):
       
       city_name = row.City
       city_id = row.City_id
       latitude = row.Latitude  
       longitude = row.Longitude


       url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

       querystring = {
       "lat": latitude, 
       "lon": longitude, 
       "radiusKm":"100",
       "limit":"16", 
       "withFlightInfoOnly":"true" 
       }

       headers = { 
       "x-rapidapi-key": safe_key["x_rapidapi_key"],
       "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
                            }

       response = requests.get(url, headers=headers, params=querystring)
       
       list_for_df.append(pd.json_normalize(response.json()['items']))
     
     return pd.concat(list_for_df, ignore_index=True)

# %%
icao_airport_codes_df = airport_data_df.loc[:, ["icao"]]
icao_airport_codes_df
# Out:
#    icao
# 0  EDDB
# 1  LFPB
# 2  LFPO
# 3  LFPG
# 4  LFOB
# 5  VAPO

# %%
for code in icao_airport_codes_df.itertuples(index=False):
    print(code.icao)
# Out:
# EDDB
# LFPB
# LFPO
# LFPG
# LFOB
# VAPO

# %%
icao_airport_names_df = airport_data_df.loc[:, ["icao", "name"]]
icao_airport_names_df
# Out:
#    icao                                 name
# 0  EDDB                   Berlin Brandenburg
# 1  LFPB                    Paris -Le Bourget
# 2  LFPO                          Paris -Orly
# 3  LFPG              Paris Charles de Gaulle
# 4  LFOB  Beauvais/Tillé Paris Beauvais Tillé
# 5  VAPO                                Pune

# %% [markdown]
# ### Extra information about icao and iata

# %% [markdown]
# - IATA stands for the International Air Transport Association, an industry trade group that represents airlines worldwide.
#
# - IATA codes are three-letter airport codes that are widely used by airlines and passengers to identify airports in ticketing, luggage tags, and flight schedules.
# - Unlike ICAO codes (used in professional aviation operations), IATA codes are more consumer-facing and are typically easier to remember.

# %% [markdown]
# - In AeroDataBox and aviation terminology, ICAO stands for the International Civil Aviation Organization.
#
# - In the context of AeroDataBox:
#
#     - ICAO codes are four-letter alphanumeric codes used to uniquely identify airports around the world. These are standardized by ICAO and commonly used in aviation operations, flight planning, and air traffic control.

# %% [markdown]
# ### **Challenge:** Arrivals information
# Using what you have been shown above, plus the skills you've learnt in the last couple of days:
# 1. In `AeroDataBox API` use the `Flight API` > `FIDS/Schedules: Airport departures and arrivals (by time range)` section
# 2. Fill out the parameters in the middle third and then copy the `python: requests` code from the right hand third
# 3. Explore the data you get back. What would be useful in your DataFrame and what can be excluded? Remember Gans wants to know about when people are arriving in the city
# 4. Make a DataFrame from the information you see as important
# 5. Condense everything you did above into a function that can take a list of ICAO codes as an input, and as an output gives you a DataFrame with the information for *tomorrows arrivals*

# %%
# your code here

url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/2024-12-03T20:00/2024-12-04T08:00"

querystring = {
    			"withLeg":"true",
                "direction":"Arrival",
                "withCancelled":"false",
                "withCodeshared":"true",
                "withCargo":"false",                    "withPrivate":"false"
    }

headers = {
	"x-rapidapi-key": safe_key["x_rapidapi_key"],
	"x-rapidapi-host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

flight = response.json()
flight
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-03 17:50Z',
#      'local': '2024-12-03 18:50+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:00Z',
#      'local': '2024-12-03 20:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:00Z',
#      'local': '2024-12-03 20:00+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 14',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABNI', 'modeS': '3C49C9', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 16:20Z',
#      'local': '2024-12-03 17:20+01:00'},
#     'revisedTime': {'utc': '2024-12-03 16:20Z',
#      'local': '2024-12-03 17:20+01:00'},
#     'terminal': '2',
#     'checkInDesk': 'C31-C33',
#     'gate': 'R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 7173',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LVG', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 16:20Z',
#      'local': '2024-12-03 17:20+01:00'},
#     'revisedTime': {'utc': '2024-12-03 16:20Z',
#      'local': '2024-12-03 17:20+01:00'},
#     'terminal': '2',
#     'checkInDesk': 'C31-C33',
#     'gate': 'R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 7173',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LVG', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 19:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 19:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:10Z',
#      'local': '2024-12-03 20:10+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:10Z',
#      'local': '2024-12-03 20:10+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'VL 1954',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGP', 'modeS': '3C48F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'Air Via', 'iata': 'VL', 'icao': 'VIM'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg',
#      'timeZone': 'Europe/Luxembourg'},
#     'scheduledTime': {'utc': '2024-12-03 17:50Z',
#      'local': '2024-12-03 18:50+01:00'},
#     'revisedTime': {'utc': '2024-12-03 17:50Z',
#      'local': '2024-12-03 18:50+01:00'},
#     'terminal': 'A',
#     'gate': 'B03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:20Z',
#      'local': '2024-12-03 20:20+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:20Z',
#      'local': '2024-12-03 20:20+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9473',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Bombardier Dash 8 Q400 / DHC-8-400'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 16:50Z',
#      'local': '2024-12-03 17:50+01:00'},
#     'revisedTime': {'utc': '2024-12-03 16:50Z',
#      'local': '2024-12-03 17:50+01:00'},
#     'terminal': '1',
#     'checkInDesk': '501-514',
#     'gate': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:30Z',
#      'local': '2024-12-03 20:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:30Z',
#      'local': '2024-12-03 20:30+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1886',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-200'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 19:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 19:00+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '78',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:30Z',
#      'local': '2024-12-03 20:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:30Z',
#      'local': '2024-12-03 20:30+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'DS 1187',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JZY', 'modeS': '4B1A66', 'model': 'Airbus A320'},
#    'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 19:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 19:00+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '78',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:30Z',
#      'local': '2024-12-03 20:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:30Z',
#      'local': '2024-12-03 20:30+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 1187',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JZY', 'modeS': '4B1A66', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LCLK',
#      'iata': 'LCA',
#      'name': 'Larnarca',
#      'timeZone': 'Asia/Nicosia'},
#     'scheduledTime': {'utc': '2024-12-03 15:40Z',
#      'local': '2024-12-03 17:40+02:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:45Z',
#      'local': '2024-12-03 20:45+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:45Z',
#      'local': '2024-12-03 20:45+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5368',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LCLK',
#      'iata': 'LCA',
#      'name': 'Larnarca',
#      'timeZone': 'Asia/Nicosia'},
#     'scheduledTime': {'utc': '2024-12-03 15:40Z',
#      'local': '2024-12-03 17:40+02:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:45Z',
#      'local': '2024-12-03 20:45+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:45Z',
#      'local': '2024-12-03 20:45+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5368',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-12-03 17:35Z',
#      'local': '2024-12-03 18:35+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:45Z',
#      'local': '2024-12-03 20:45+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:45Z',
#      'local': '2024-12-03 20:45+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 41',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QEL', 'modeS': '4D224D', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 18:00+00:00'},
#     'terminal': 'N',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:50Z',
#      'local': '2024-12-03 20:50+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:50Z',
#      'local': '2024-12-03 20:50+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 8625',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZWX',
#     'modeS': '406B90',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-12-03 18:35Z',
#      'local': '2024-12-03 19:35+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:35Z',
#      'local': '2024-12-03 19:35+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'B18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:50Z',
#      'local': '2024-12-03 20:50+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:50Z',
#      'local': '2024-12-03 20:50+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1783',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-NXW', 'modeS': '4864EA', 'model': 'E 195-E2'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 17:55Z',
#      'local': '2024-12-03 17:55+00:00'},
#     'revisedTime': {'utc': '2024-12-03 17:55Z',
#      'local': '2024-12-03 17:55+00:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:50Z',
#      'local': '2024-12-03 20:50+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:50Z',
#      'local': '2024-12-03 20:50+01:00'},
#     'terminal': '1',
#     'gate': 'Y10',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2201',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZTC', 'modeS': '405F13', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-12-03 18:15Z',
#      'local': '2024-12-03 19:15+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5066',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKV', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-12-03 18:15Z',
#      'local': '2024-12-03 19:15+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5066',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKV', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-03 18:45Z',
#      'local': '2024-12-03 19:45+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:45Z',
#      'local': '2024-12-03 19:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 200',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDL', 'modeS': '3C648C', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EPWA',
#      'iata': 'WAW',
#      'name': 'Warsaw',
#      'timeZone': 'Europe/Warsaw'},
#     'scheduledTime': {'utc': '2024-12-03 18:40Z',
#      'local': '2024-12-03 19:40+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:00Z',
#      'local': '2024-12-03 21:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:00Z',
#      'local': '2024-12-03 21:00+01:00'},
#     'terminal': '1',
#     'gate': 'A22',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 391',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'departure': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 14:45Z',
#      'local': '2024-12-03 14:45+00:00'},
#     'revisedTime': {'utc': '2024-12-03 14:45Z',
#      'local': '2024-12-03 14:45+00:00'},
#     'terminal': 'C',
#     'checkInDesk': '221-226',
#     'gate': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5114',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 14:45Z',
#      'local': '2024-12-03 14:45+00:00'},
#     'revisedTime': {'utc': '2024-12-03 14:45Z',
#      'local': '2024-12-03 14:45+00:00'},
#     'terminal': 'C',
#     'checkInDesk': '221-226',
#     'gate': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5114',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EGLC',
#      'iata': 'LCY',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 18:30Z',
#      'local': '2024-12-03 18:30+00:00'},
#     'revisedTime': {'utc': '2024-12-03 18:30Z',
#      'local': '2024-12-03 18:30+00:00'},
#     'gate': '5',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:10Z',
#      'local': '2024-12-03 21:10+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:10Z',
#      'local': '2024-12-03 21:10+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8495',
#    'callSign': 'CFE8495',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYR', 'modeS': '40676A', 'model': 'Embraer 190'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LBWN',
#      'iata': 'VAR',
#      'name': 'Varna',
#      'timeZone': 'Europe/Sofia'},
#     'scheduledTime': {'utc': '2024-12-03 17:40Z',
#      'local': '2024-12-03 19:40+02:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:15Z',
#      'local': '2024-12-03 21:15+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:15Z',
#      'local': '2024-12-03 21:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 4515',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HA-LZR',
#     'modeS': '471FA7',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#   {'departure': {'airport': {'icao': 'EGSS',
#      'iata': 'STN',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 18:45Z',
#      'local': '2024-12-03 18:45+00:00'},
#     'revisedTime': {'utc': '2024-12-03 18:45Z',
#      'local': '2024-12-03 18:45+00:00'},
#     'terminal': '1',
#     'gate': '48',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:25Z',
#      'local': '2024-12-03 21:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:25Z',
#      'local': '2024-12-03 21:25+01:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 147',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-DPR', 'modeS': '4CA4F5', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LWSK',
#      'iata': 'SKP',
#      'name': 'Skopje',
#      'timeZone': 'Europe/Skopje'},
#     'scheduledTime': {'utc': '2024-12-03 18:05Z',
#      'local': '2024-12-03 19:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:05Z',
#      'local': '2024-12-03 19:05+01:00'},
#     'gate': '204',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:30Z',
#      'local': '2024-12-03 21:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:30Z',
#      'local': '2024-12-03 21:30+01:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 4739',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HA-LYQ', 'modeS': '471F8C', 'model': 'Airbus A320'},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-12-03 17:40Z',
#      'local': '2024-12-03 20:40+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:40Z',
#      'local': '2024-12-03 21:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:40Z',
#      'local': '2024-12-03 21:40+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1727',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-12-03 19:10Z',
#      'local': '2024-12-03 20:10+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:10Z',
#      'local': '2024-12-03 20:10+01:00'},
#     'checkInDesk': '2(5)',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:50Z',
#      'local': '2024-12-03 21:50+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:50Z',
#      'local': '2024-12-03 21:50+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8763',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWV', 'modeS': '3C56F6', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 18:55Z',
#      'local': '2024-12-03 18:55+00:00'},
#     'revisedTime': {'utc': '2024-12-03 18:55Z',
#      'local': '2024-12-03 18:55+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:55Z',
#      'local': '2024-12-03 21:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:55Z',
#      'local': '2024-12-03 21:55+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 988',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-12-03 19:35Z',
#      'local': '2024-12-03 20:35+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:35Z',
#      'local': '2024-12-03 20:35+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'C9',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 20:55Z',
#      'local': '2024-12-03 21:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:55Z',
#      'local': '2024-12-03 21:55+01:00'},
#     'terminal': '1',
#     'gate': 'A17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1785',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXZ',
#     'modeS': '484557',
#     'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'OMDB',
#      'iata': 'DXB',
#      'name': 'Dubai',
#      'timeZone': 'Asia/Dubai'},
#     'scheduledTime': {'utc': '2024-12-03 14:00Z',
#      'local': '2024-12-03 18:00+04:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:00Z',
#      'local': '2024-12-03 22:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:00Z',
#      'local': '2024-12-03 22:00+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 1151',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENF', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 18:25Z',
#      'local': '2024-12-03 19:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:25Z',
#      'local': '2024-12-03 19:25+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:10Z',
#      'local': '2024-12-03 22:10+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:10Z',
#      'local': '2024-12-03 22:10+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 149',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EMM', 'modeS': '4CA855', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-12-03 20:00Z',
#      'local': '2024-12-03 21:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:00Z',
#      'local': '2024-12-03 21:00+01:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:15Z',
#      'local': '2024-12-03 22:15+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:15Z',
#      'local': '2024-12-03 22:15+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 239',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo',
#      'timeZone': 'Asia/Jerusalem'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 18:25Z',
#      'local': '2024-12-03 19:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:15Z',
#      'local': '2024-12-03 22:15+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BZ 272',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-KAR', 'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Blue Bird', 'iata': 'BZ', 'icao': 'BBG'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels',
#      'timeZone': 'Europe/Brussels'},
#     'scheduledTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'checkInDesk': '05',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:20Z',
#      'local': '2024-12-03 22:20+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:20Z',
#      'local': '2024-12-03 22:20+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2591',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'checkInDesk': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:20Z',
#      'local': '2024-12-03 22:20+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:20Z',
#      'local': '2024-12-03 22:20+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 962',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-IJK', 'modeS': '4B1614', 'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-03 19:40Z',
#      'local': '2024-12-03 20:40+01:00'},
#     'terminal': '2D',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5150',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-03 19:40Z',
#      'local': '2024-12-03 20:40+01:00'},
#     'terminal': '2D',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5150',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'GCFV',
#      'iata': 'FUE',
#      'name': 'Fuerteventura Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'revisedTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'terminal': '1',
#     'checkInDesk': '10-13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5102',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'GCFV',
#      'iata': 'FUE',
#      'name': 'Fuerteventura Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'revisedTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'terminal': '1',
#     'checkInDesk': '10-13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5102',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LPPT',
#      'iata': 'LIS',
#      'name': 'Lisbon',
#      'timeZone': 'Europe/Lisbon'},
#     'scheduledTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 18:00+00:00'},
#     'revisedTime': {'utc': '2024-12-03 18:00Z',
#      'local': '2024-12-03 18:00+00:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1143',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IGI',
#     'modeS': '4CADBB',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-03 20:15Z',
#      'local': '2024-12-03 21:15+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:15Z',
#      'local': '2024-12-03 21:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 202',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISW', 'model': 'Airbus A321-200'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'HEGN',
#      'iata': 'HRG',
#      'name': 'Hurghada',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-12-03 16:15Z',
#      'local': '2024-12-03 18:15+02:00'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:25Z',
#      'local': '2024-12-03 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8983',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'GCFV',
#      'iata': 'FUE',
#      'name': 'Fuerteventura Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 16:40Z',
#      'local': '2024-12-03 16:40+00:00'},
#     'revisedTime': {'utc': '2024-12-03 16:40Z',
#      'local': '2024-12-03 16:40+00:00'},
#     'terminal': '1',
#     'checkInDesk': '02-08',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:30Z',
#      'local': '2024-12-03 22:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:30Z',
#      'local': '2024-12-03 22:30+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3355',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VVJ',
#     'modeS': '4D24CB',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'GCLP',
#      'iata': 'LPA',
#      'name': 'Gran Canaria Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'revisedTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'terminal': '1',
#     'checkInDesk': '224-226',
#     'gate': 'C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:30Z',
#      'local': '2024-12-03 22:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:30Z',
#      'local': '2024-12-03 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5112',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INO', 'modeS': '4402F0', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'GCLP',
#      'iata': 'LPA',
#      'name': 'Gran Canaria Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'revisedTime': {'utc': '2024-12-03 16:25Z',
#      'local': '2024-12-03 16:25+00:00'},
#     'terminal': '1',
#     'checkInDesk': '224-226',
#     'gate': 'C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:30Z',
#      'local': '2024-12-03 22:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:30Z',
#      'local': '2024-12-03 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5112',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INO', 'modeS': '4402F0', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-12-03 20:35Z',
#      'local': '2024-12-03 21:35+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:35Z',
#      'local': '2024-12-03 21:35+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5264',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-12-03 20:35Z',
#      'local': '2024-12-03 21:35+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:35Z',
#      'local': '2024-12-03 21:35+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5264',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LSGG',
#      'iata': 'GVA',
#      'name': 'Geneva',
#      'timeZone': 'Europe/Zurich'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5186',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LSGG',
#      'iata': 'GVA',
#      'name': 'Geneva',
#      'timeZone': 'Europe/Zurich'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5186',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'checkInDesk': '2(5)',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5188',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICW', 'modeS': '440047', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:05Z',
#      'local': '2024-12-03 21:05+01:00'},
#     'checkInDesk': '2(5)',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5188',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICW', 'modeS': '440047', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-03 19:55Z',
#      'local': '2024-12-03 20:55+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1134',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A220-300'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-03 20:30Z',
#      'local': '2024-12-03 21:30+01:00'},
#     'revisedTime': {'utc': '2024-12-03 20:30Z',
#      'local': '2024-12-03 21:30+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:40Z',
#      'local': '2024-12-03 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1958',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZW',
#     'modeS': '3C6757',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LEMG',
#      'iata': 'AGP',
#      'name': 'Málaga',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 18:05Z',
#      'local': '2024-12-03 19:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:06Z',
#      'local': '2024-12-03 19:06+01:00'},
#     'terminal': 'PAX',
#     'checkInDesk': '255-261',
#     'gate': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:45Z',
#      'local': '2024-12-03 22:45+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:45Z',
#      'local': '2024-12-03 22:45+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5106',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDU', 'modeS': '440DAF', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LEMG',
#      'iata': 'AGP',
#      'name': 'Málaga',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 18:05Z',
#      'local': '2024-12-03 19:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 18:06Z',
#      'local': '2024-12-03 19:06+01:00'},
#     'terminal': 'PAX',
#     'checkInDesk': '255-261',
#     'gate': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 21:45Z',
#      'local': '2024-12-03 22:45+01:00'},
#     'revisedTime': {'utc': '2024-12-03 21:45Z',
#      'local': '2024-12-03 22:45+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5106',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDU', 'modeS': '440DAF', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-12-03 16:55Z',
#      'local': '2024-12-03 16:55+00:00'},
#     'revisedTime': {'utc': '2024-12-03 16:55Z',
#      'local': '2024-12-03 16:55+00:00'},
#     'terminal': 'C',
#     'checkInDesk': '202-210',
#     'gate': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 22:00Z',
#      'local': '2024-12-03 23:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 22:00Z',
#      'local': '2024-12-03 23:00+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2419',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EVO', 'modeS': '4CA9EC', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 20:10Z',
#      'local': '2024-12-03 20:10+00:00'},
#     'terminal': 'N',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 22:00Z',
#      'local': '2024-12-03 23:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 22:00Z',
#      'local': '2024-12-03 23:00+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 8631',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICI', 'modeS': '44046D', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-12-03 20:10Z',
#      'local': '2024-12-03 20:10+00:00'},
#     'terminal': 'N',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 22:00Z',
#      'local': '2024-12-03 23:00+01:00'},
#     'revisedTime': {'utc': '2024-12-03 22:00Z',
#      'local': '2024-12-03 23:00+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 8631',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICI', 'modeS': '44046D', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LEMD',
#      'iata': 'MAD',
#      'name': 'Madrid',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'terminal': '4',
#     'checkInDesk': '850-859',
#     'gate': 'K',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 22:10Z',
#      'local': '2024-12-03 23:10+01:00'},
#     'revisedTime': {'utc': '2024-12-03 22:10Z',
#      'local': '2024-12-03 23:10+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'IB 1809',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}},
#   {'departure': {'airport': {'icao': 'LEMD',
#      'iata': 'MAD',
#      'name': 'Madrid',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'revisedTime': {'utc': '2024-12-03 19:05Z',
#      'local': '2024-12-03 20:05+01:00'},
#     'terminal': '4',
#     'checkInDesk': '850-859',
#     'gate': 'K',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-03 22:10Z',
#      'local': '2024-12-03 23:10+01:00'},
#     'revisedTime': {'utc': '2024-12-03 22:10Z',
#      'local': '2024-12-03 23:10+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 1809',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'scheduledTime': {'utc': '2024-12-04 00:45Z',
#      'local': '2024-12-04 00:45+00:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 05:15Z',
#      'local': '2024-12-04 06:15+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'FI 518',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737'},
#    'airline': {'name': 'Icelandair', 'iata': 'FI', 'icao': 'ICE'}},
#   {'departure': {'airport': {'icao': 'ZBAA',
#      'iata': 'PEK',
#      'name': 'Beijing',
#      'timeZone': 'Asia/Shanghai'},
#     'scheduledTime': {'utc': '2024-12-03 19:40Z',
#      'local': '2024-12-04 03:40+08:00'},
#     'revisedTime': {'utc': '2024-12-03 19:40Z',
#      'local': '2024-12-04 03:40+08:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 05:40Z',
#      'local': '2024-12-04 06:40+01:00'},
#     'revisedTime': {'utc': '2024-12-04 05:40Z',
#      'local': '2024-12-04 06:40+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'HU 489',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#   {'departure': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha',
#      'timeZone': 'Asia/Qatar'},
#     'scheduledTime': {'utc': '2024-12-03 23:40Z',
#      'local': '2024-12-04 02:40+03:00'},
#     'revisedTime': {'utc': '2024-12-03 23:40Z',
#      'local': '2024-12-04 02:40+03:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 05:55Z',
#      'local': '2024-12-04 06:55+01:00'},
#     'revisedTime': {'utc': '2024-12-04 05:55Z',
#      'local': '2024-12-04 06:55+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 79',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-04 05:20Z',
#      'local': '2024-12-04 06:20+01:00'},
#     'revisedTime': {'utc': '2024-12-04 05:20Z',
#      'local': '2024-12-04 06:20+01:00'},
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 06:35Z',
#      'local': '2024-12-04 07:35+01:00'},
#     'revisedTime': {'utc': '2024-12-04 06:35Z',
#      'local': '2024-12-04 07:35+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8001',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-04 05:30Z',
#      'local': '2024-12-04 06:30+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 06:40Z',
#      'local': '2024-12-04 07:40+01:00'},
#     'revisedTime': {'utc': '2024-12-04 06:40Z',
#      'local': '2024-12-04 07:40+01:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-04 05:15Z',
#      'local': '2024-12-04 06:15+01:00'},
#     'revisedTime': {'utc': '2024-12-04 05:15Z',
#      'local': '2024-12-04 06:15+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 06:45Z',
#      'local': '2024-12-04 07:45+01:00'},
#     'revisedTime': {'utc': '2024-12-04 06:45Z',
#      'local': '2024-12-04 07:45+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DS 1185',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-AYN',
#     'modeS': '4B027D',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-12-04 05:15Z',
#      'local': '2024-12-04 06:15+01:00'},
#     'revisedTime': {'utc': '2024-12-04 05:15Z',
#      'local': '2024-12-04 06:15+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 06:45Z',
#      'local': '2024-12-04 07:45+01:00'},
#     'revisedTime': {'utc': '2024-12-04 06:45Z',
#      'local': '2024-12-04 07:45+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 1185',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-AYN',
#     'modeS': '4B027D',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'KEWR',
#      'iata': 'EWR',
#      'name': 'Newark',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-12-03 22:50Z',
#      'local': '2024-12-03 17:50-05:00'},
#     'terminal': 'C',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 06:55Z',
#      'local': '2024-12-04 07:55+01:00'},
#     'revisedTime': {'utc': '2024-12-04 06:55Z',
#      'local': '2024-12-04 07:55+01:00'},
#     'terminal': '1',
#     'gate': 'Y17',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'UA 962',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 767-400(ER)'},
#    'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-12-04 05:45Z',
#      'local': '2024-12-04 06:45+01:00'},
#     'revisedTime': {'utc': '2024-12-04 05:45Z',
#      'local': '2024-12-04 06:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-12-04 06:55Z',
#      'local': '2024-12-04 07:55+01:00'},
#     'revisedTime': {'utc': '2024-12-04 06:55Z',
#      'local': '2024-12-04 07:55+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 170',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIWK',
#     'modeS': '3C66EB',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}]}

# %% [markdown]
# - departure airport icao
# - arrival revisedTime local
# - arrival airport airline icao
# - number #Flight number
# -

# %%
flight["arrivals"]
# Out:
# [{'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-03 17:50Z',
#     'local': '2024-12-03 18:50+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:00Z',
#     'local': '2024-12-03 20:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:00Z',
#     'local': '2024-12-03 20:00+01:00'},
#    'terminal': '1',
#    'gate': 'B02',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 14',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABNI', 'modeS': '3C49C9', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 16:20Z',
#     'local': '2024-12-03 17:20+01:00'},
#    'revisedTime': {'utc': '2024-12-03 16:20Z',
#     'local': '2024-12-03 17:20+01:00'},
#    'terminal': '2',
#    'checkInDesk': 'C31-C33',
#    'gate': 'R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 7173',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LVG', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 16:20Z',
#     'local': '2024-12-03 17:20+01:00'},
#    'revisedTime': {'utc': '2024-12-03 16:20Z',
#     'local': '2024-12-03 17:20+01:00'},
#    'terminal': '2',
#    'checkInDesk': 'C31-C33',
#    'gate': 'R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 7173',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LVG', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 19:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 19:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:10Z',
#     'local': '2024-12-03 20:10+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:10Z',
#     'local': '2024-12-03 20:10+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'VL 1954',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGP', 'modeS': '3C48F0', 'model': 'Airbus A319'},
#   'airline': {'name': 'Air Via', 'iata': 'VL', 'icao': 'VIM'}},
#  {'departure': {'airport': {'icao': 'ELLX',
#     'iata': 'LUX',
#     'name': 'Luxembourg',
#     'timeZone': 'Europe/Luxembourg'},
#    'scheduledTime': {'utc': '2024-12-03 17:50Z',
#     'local': '2024-12-03 18:50+01:00'},
#    'revisedTime': {'utc': '2024-12-03 17:50Z',
#     'local': '2024-12-03 18:50+01:00'},
#    'terminal': 'A',
#    'gate': 'B03',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:20Z',
#     'local': '2024-12-03 20:20+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:20Z',
#     'local': '2024-12-03 20:20+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LG 9473',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Bombardier Dash 8 Q400 / DHC-8-400'},
#   'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 16:50Z',
#     'local': '2024-12-03 17:50+01:00'},
#    'revisedTime': {'utc': '2024-12-03 16:50Z',
#     'local': '2024-12-03 17:50+01:00'},
#    'terminal': '1',
#    'checkInDesk': '501-514',
#    'gate': 'B',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:30Z',
#     'local': '2024-12-03 20:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:30Z',
#     'local': '2024-12-03 20:30+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'VY 1886',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A321-200'},
#   'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 19:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 19:00+01:00'},
#    'checkInDesk': '42-50',
#    'gate': '78',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:30Z',
#     'local': '2024-12-03 20:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:30Z',
#     'local': '2024-12-03 20:30+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'DS 1187',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JZY', 'modeS': '4B1A66', 'model': 'Airbus A320'},
#   'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 19:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 19:00+01:00'},
#    'checkInDesk': '42-50',
#    'gate': '78',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:30Z',
#     'local': '2024-12-03 20:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:30Z',
#     'local': '2024-12-03 20:30+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 1187',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-JZY', 'modeS': '4B1A66', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LCLK',
#     'iata': 'LCA',
#     'name': 'Larnarca',
#     'timeZone': 'Asia/Nicosia'},
#    'scheduledTime': {'utc': '2024-12-03 15:40Z',
#     'local': '2024-12-03 17:40+02:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:45Z',
#     'local': '2024-12-03 20:45+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:45Z',
#     'local': '2024-12-03 20:45+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5368',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICL',
#    'modeS': '4404A4',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LCLK',
#     'iata': 'LCA',
#     'name': 'Larnarca',
#     'timeZone': 'Asia/Nicosia'},
#    'scheduledTime': {'utc': '2024-12-03 15:40Z',
#     'local': '2024-12-03 17:40+02:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:45Z',
#     'local': '2024-12-03 20:45+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:45Z',
#     'local': '2024-12-03 20:45+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5368',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICL',
#    'modeS': '4404A4',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-12-03 17:35Z',
#     'local': '2024-12-03 18:35+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:45Z',
#     'local': '2024-12-03 20:45+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:45Z',
#     'local': '2024-12-03 20:45+01:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 41',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QEL', 'modeS': '4D224D', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EGCC',
#     'iata': 'MAN',
#     'name': 'Manchester',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 17:55Z',
#     'local': '2024-12-03 17:55+00:00'},
#    'revisedTime': {'utc': '2024-12-03 17:55Z',
#     'local': '2024-12-03 17:55+00:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:50Z',
#     'local': '2024-12-03 20:50+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:50Z',
#     'local': '2024-12-03 20:50+01:00'},
#    'terminal': '1',
#    'gate': 'Y10',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 2201',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EZTC', 'modeS': '405F13', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EGKK',
#     'iata': 'LGW',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 18:00+00:00'},
#    'terminal': 'N',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:50Z',
#     'local': '2024-12-03 20:50+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:50Z',
#     'local': '2024-12-03 20:50+01:00'},
#    'terminal': '1',
#    'gate': 'Y03',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 8625',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EZWX',
#    'modeS': '406B90',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-12-03 18:35Z',
#     'local': '2024-12-03 19:35+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:35Z',
#     'local': '2024-12-03 19:35+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'B18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:50Z',
#     'local': '2024-12-03 20:50+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:50Z',
#     'local': '2024-12-03 20:50+01:00'},
#    'terminal': '1',
#    'gate': 'B17',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1783',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-NXW', 'modeS': '4864EA', 'model': 'E 195-E2'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-12-03 18:15Z',
#     'local': '2024-12-03 19:15+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5066',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LKV', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-12-03 18:15Z',
#     'local': '2024-12-03 19:15+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5066',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LKV', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-03 18:45Z',
#     'local': '2024-12-03 19:45+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:45Z',
#     'local': '2024-12-03 19:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 200',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIDL', 'modeS': '3C648C', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EPWA',
#     'iata': 'WAW',
#     'name': 'Warsaw',
#     'timeZone': 'Europe/Warsaw'},
#    'scheduledTime': {'utc': '2024-12-03 18:40Z',
#     'local': '2024-12-03 19:40+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:00Z',
#     'local': '2024-12-03 21:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:00Z',
#     'local': '2024-12-03 21:00+01:00'},
#    'terminal': '1',
#    'gate': 'A22',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LO 391',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Embraer 195'},
#   'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#  {'departure': {'airport': {'icao': 'GCTS',
#     'iata': 'TFS',
#     'name': 'Tenerife Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 14:45Z',
#     'local': '2024-12-03 14:45+00:00'},
#    'revisedTime': {'utc': '2024-12-03 14:45Z',
#     'local': '2024-12-03 14:45+00:00'},
#    'terminal': 'C',
#    'checkInDesk': '221-226',
#    'gate': 'B',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5114',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'GCTS',
#     'iata': 'TFS',
#     'name': 'Tenerife Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 14:45Z',
#     'local': '2024-12-03 14:45+00:00'},
#    'revisedTime': {'utc': '2024-12-03 14:45Z',
#     'local': '2024-12-03 14:45+00:00'},
#    'terminal': 'C',
#    'checkInDesk': '221-226',
#    'gate': 'B',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5114',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EGLC',
#     'iata': 'LCY',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 18:30Z',
#     'local': '2024-12-03 18:30+00:00'},
#    'revisedTime': {'utc': '2024-12-03 18:30Z',
#     'local': '2024-12-03 18:30+00:00'},
#    'gate': '5',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:10Z',
#     'local': '2024-12-03 21:10+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:10Z',
#     'local': '2024-12-03 21:10+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 8495',
#   'callSign': 'CFE8495',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-LCYR', 'modeS': '40676A', 'model': 'Embraer 190'},
#   'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'LBWN',
#     'iata': 'VAR',
#     'name': 'Varna',
#     'timeZone': 'Europe/Sofia'},
#    'scheduledTime': {'utc': '2024-12-03 17:40Z',
#     'local': '2024-12-03 19:40+02:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:15Z',
#     'local': '2024-12-03 21:15+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:15Z',
#     'local': '2024-12-03 21:15+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'W6 4515',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HA-LZR', 'modeS': '471FA7', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#  {'departure': {'airport': {'icao': 'EGSS',
#     'iata': 'STN',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 18:45Z',
#     'local': '2024-12-03 18:45+00:00'},
#    'revisedTime': {'utc': '2024-12-03 18:45Z',
#     'local': '2024-12-03 18:45+00:00'},
#    'terminal': '1',
#    'gate': '48',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:25Z',
#     'local': '2024-12-03 21:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:25Z',
#     'local': '2024-12-03 21:25+01:00'},
#    'terminal': '2',
#    'gate': 'Z40',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 147',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-DPR', 'modeS': '4CA4F5', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LWSK',
#     'iata': 'SKP',
#     'name': 'Skopje',
#     'timeZone': 'Europe/Skopje'},
#    'scheduledTime': {'utc': '2024-12-03 18:05Z',
#     'local': '2024-12-03 19:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:05Z',
#     'local': '2024-12-03 19:05+01:00'},
#    'gate': '204',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:30Z',
#     'local': '2024-12-03 21:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:30Z',
#     'local': '2024-12-03 21:30+01:00'},
#    'terminal': '2',
#    'gate': 'Z42',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'W6 4739',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HA-LYQ', 'modeS': '471F8C', 'model': 'Airbus A320'},
#   'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#  {'departure': {'airport': {'icao': 'LTFM',
#     'iata': 'IST',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-12-03 17:40Z',
#     'local': '2024-12-03 20:40+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:40Z',
#     'local': '2024-12-03 21:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:40Z',
#     'local': '2024-12-03 21:40+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1727',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A321-100'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-12-03 19:10Z',
#     'local': '2024-12-03 20:10+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:10Z',
#     'local': '2024-12-03 20:10+01:00'},
#    'checkInDesk': '2(5)',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:50Z',
#     'local': '2024-12-03 21:50+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:50Z',
#     'local': '2024-12-03 21:50+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8763',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWV', 'modeS': '3C56F6', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EGLL',
#     'iata': 'LHR',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 18:55Z',
#     'local': '2024-12-03 18:55+00:00'},
#    'revisedTime': {'utc': '2024-12-03 18:55Z',
#     'local': '2024-12-03 18:55+00:00'},
#    'terminal': '5',
#    'checkInDesk': 'D',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:55Z',
#     'local': '2024-12-03 21:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:55Z',
#     'local': '2024-12-03 21:55+01:00'},
#    'terminal': '1',
#    'gate': 'X10',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 988',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A319'},
#   'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-12-03 19:35Z',
#     'local': '2024-12-03 20:35+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:35Z',
#     'local': '2024-12-03 20:35+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'C9',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 20:55Z',
#     'local': '2024-12-03 21:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:55Z',
#     'local': '2024-12-03 21:55+01:00'},
#    'terminal': '1',
#    'gate': 'A17',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1785',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BXZ',
#    'modeS': '484557',
#    'model': 'Boeing 737-700 (winglets)'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'OMDB',
#     'iata': 'DXB',
#     'name': 'Dubai',
#     'timeZone': 'Asia/Dubai'},
#    'scheduledTime': {'utc': '2024-12-03 14:00Z',
#     'local': '2024-12-03 18:00+04:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:00Z',
#     'local': '2024-12-03 22:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:00Z',
#     'local': '2024-12-03 22:00+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 1151',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AENF', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 18:25Z',
#     'local': '2024-12-03 19:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:25Z',
#     'local': '2024-12-03 19:25+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:10Z',
#     'local': '2024-12-03 22:10+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:10Z',
#     'local': '2024-12-03 22:10+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 149',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EMM', 'modeS': '4CA855', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-12-03 20:00Z',
#     'local': '2024-12-03 21:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:00Z',
#     'local': '2024-12-03 21:00+01:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:15Z',
#     'local': '2024-12-03 22:15+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:15Z',
#     'local': '2024-12-03 22:15+01:00'},
#    'terminal': '1',
#    'gate': 'B02',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 239',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LLBG',
#     'iata': 'TLV',
#     'name': 'Tel Aviv Yafo',
#     'timeZone': 'Asia/Jerusalem'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 18:25Z',
#     'local': '2024-12-03 19:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:15Z',
#     'local': '2024-12-03 22:15+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'BZ 272',
#   'status': 'Delayed',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-KAR', 'model': 'Boeing 737-800 (winglets)'},
#   'airline': {'name': 'Blue Bird', 'iata': 'BZ', 'icao': 'BBG'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'checkInDesk': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:20Z',
#     'local': '2024-12-03 22:20+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:20Z',
#     'local': '2024-12-03 22:20+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 962',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-IJK', 'modeS': '4B1614', 'model': 'Airbus A320'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EBBR',
#     'iata': 'BRU',
#     'name': 'Brussels',
#     'timeZone': 'Europe/Brussels'},
#    'scheduledTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'checkInDesk': '05',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:20Z',
#     'local': '2024-12-03 22:20+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:20Z',
#     'local': '2024-12-03 22:20+01:00'},
#    'terminal': '1',
#    'gate': 'B17',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'SN 2591',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A320'},
#   'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#  {'departure': {'airport': {'icao': 'LPPT',
#     'iata': 'LIS',
#     'name': 'Lisbon',
#     'timeZone': 'Europe/Lisbon'},
#    'scheduledTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 18:00+00:00'},
#    'revisedTime': {'utc': '2024-12-03 18:00Z',
#     'local': '2024-12-03 18:00+00:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 1143',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-IGI',
#    'modeS': '4CADBB',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'HEGN',
#     'iata': 'HRG',
#     'name': 'Hurghada',
#     'timeZone': 'Africa/Cairo'},
#    'scheduledTime': {'utc': '2024-12-03 16:15Z',
#     'local': '2024-12-03 18:15+02:00'},
#    'terminal': '2',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '1',
#    'gate': 'Y03',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8983',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AENH', 'modeS': '3C55C8', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'GCFV',
#     'iata': 'FUE',
#     'name': 'Fuerteventura Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'revisedTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'terminal': '1',
#    'checkInDesk': '10-13',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5102',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'GCFV',
#     'iata': 'FUE',
#     'name': 'Fuerteventura Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'revisedTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'terminal': '1',
#    'checkInDesk': '10-13',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5102',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDS', 'modeS': '440DA5', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-03 19:40Z',
#     'local': '2024-12-03 20:40+01:00'},
#    'terminal': '2D',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5150',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-03 19:40Z',
#     'local': '2024-12-03 20:40+01:00'},
#    'terminal': '2D',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5150',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-03 20:15Z',
#     'local': '2024-12-03 21:15+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:15Z',
#     'local': '2024-12-03 21:15+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A16',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:25Z',
#     'local': '2024-12-03 22:25+01:00'},
#    'terminal': '1',
#    'gate': 'B10',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 202',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AISW', 'model': 'Airbus A321-200'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'GCLP',
#     'iata': 'LPA',
#     'name': 'Gran Canaria Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'revisedTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'terminal': '1',
#    'checkInDesk': '224-226',
#    'gate': 'C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:30Z',
#     'local': '2024-12-03 22:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:30Z',
#     'local': '2024-12-03 22:30+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5112',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-INO', 'modeS': '4402F0', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'GCLP',
#     'iata': 'LPA',
#     'name': 'Gran Canaria Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'revisedTime': {'utc': '2024-12-03 16:25Z',
#     'local': '2024-12-03 16:25+00:00'},
#    'terminal': '1',
#    'checkInDesk': '224-226',
#    'gate': 'C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:30Z',
#     'local': '2024-12-03 22:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:30Z',
#     'local': '2024-12-03 22:30+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5112',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-INO', 'modeS': '4402F0', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'GCFV',
#     'iata': 'FUE',
#     'name': 'Fuerteventura Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 16:40Z',
#     'local': '2024-12-03 16:40+00:00'},
#    'revisedTime': {'utc': '2024-12-03 16:40Z',
#     'local': '2024-12-03 16:40+00:00'},
#    'terminal': '1',
#    'checkInDesk': '02-08',
#    'gate': 'A',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:30Z',
#     'local': '2024-12-03 22:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:30Z',
#     'local': '2024-12-03 22:30+01:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3355',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VVJ',
#    'modeS': '4D24CB',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen',
#     'timeZone': 'Europe/Copenhagen'},
#    'scheduledTime': {'utc': '2024-12-03 20:35Z',
#     'local': '2024-12-03 21:35+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:35Z',
#     'local': '2024-12-03 21:35+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5264',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen',
#     'timeZone': 'Europe/Copenhagen'},
#    'scheduledTime': {'utc': '2024-12-03 20:35Z',
#     'local': '2024-12-03 21:35+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:35Z',
#     'local': '2024-12-03 21:35+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5264',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LSGG',
#     'iata': 'GVA',
#     'name': 'Geneva',
#     'timeZone': 'Europe/Zurich'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5186',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LSGG',
#     'iata': 'GVA',
#     'name': 'Geneva',
#     'timeZone': 'Europe/Zurich'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5186',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'checkInDesk': '2(5)',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5188',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICW', 'modeS': '440047', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:05Z',
#     'local': '2024-12-03 21:05+01:00'},
#    'checkInDesk': '2(5)',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5188',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICW', 'modeS': '440047', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-03 20:30Z',
#     'local': '2024-12-03 21:30+01:00'},
#    'revisedTime': {'utc': '2024-12-03 20:30Z',
#     'local': '2024-12-03 21:30+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'A20',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1958',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIZW',
#    'modeS': '3C6757',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-03 19:55Z',
#     'local': '2024-12-03 20:55+01:00'},
#    'terminal': '2F',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:40Z',
#     'local': '2024-12-03 22:40+01:00'},
#    'terminal': '1',
#    'gate': 'A06',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1134',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A220-300'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'LEMG',
#     'iata': 'AGP',
#     'name': 'Málaga',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 18:05Z',
#     'local': '2024-12-03 19:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:06Z',
#     'local': '2024-12-03 19:06+01:00'},
#    'terminal': 'PAX',
#    'checkInDesk': '255-261',
#    'gate': 'D',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:45Z',
#     'local': '2024-12-03 22:45+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:45Z',
#     'local': '2024-12-03 22:45+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5106',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDU', 'modeS': '440DAF', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LEMG',
#     'iata': 'AGP',
#     'name': 'Málaga',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 18:05Z',
#     'local': '2024-12-03 19:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 18:06Z',
#     'local': '2024-12-03 19:06+01:00'},
#    'terminal': 'PAX',
#    'checkInDesk': '255-261',
#    'gate': 'D',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 21:45Z',
#     'local': '2024-12-03 22:45+01:00'},
#    'revisedTime': {'utc': '2024-12-03 21:45Z',
#     'local': '2024-12-03 22:45+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5106',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDU', 'modeS': '440DAF', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EGKK',
#     'iata': 'LGW',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 20:10Z',
#     'local': '2024-12-03 20:10+00:00'},
#    'terminal': 'N',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 22:00Z',
#     'local': '2024-12-03 23:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 22:00Z',
#     'local': '2024-12-03 23:00+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 8631',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICI', 'modeS': '44046D', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EGKK',
#     'iata': 'LGW',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-12-03 20:10Z',
#     'local': '2024-12-03 20:10+00:00'},
#    'terminal': 'N',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 22:00Z',
#     'local': '2024-12-03 23:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 22:00Z',
#     'local': '2024-12-03 23:00+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 8631',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICI', 'modeS': '44046D', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'GCTS',
#     'iata': 'TFS',
#     'name': 'Tenerife Island',
#     'timeZone': 'Atlantic/Canary'},
#    'scheduledTime': {'utc': '2024-12-03 16:55Z',
#     'local': '2024-12-03 16:55+00:00'},
#    'revisedTime': {'utc': '2024-12-03 16:55Z',
#     'local': '2024-12-03 16:55+00:00'},
#    'terminal': 'C',
#    'checkInDesk': '202-210',
#    'gate': 'B',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 22:00Z',
#     'local': '2024-12-03 23:00+01:00'},
#    'revisedTime': {'utc': '2024-12-03 22:00Z',
#     'local': '2024-12-03 23:00+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 2419',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EVO', 'modeS': '4CA9EC', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LEMD',
#     'iata': 'MAD',
#     'name': 'Madrid',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'terminal': '4',
#    'checkInDesk': '850-859',
#    'gate': 'K',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 22:10Z',
#     'local': '2024-12-03 23:10+01:00'},
#    'revisedTime': {'utc': '2024-12-03 22:10Z',
#     'local': '2024-12-03 23:10+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'IB 1809',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A320'},
#   'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}},
#  {'departure': {'airport': {'icao': 'LEMD',
#     'iata': 'MAD',
#     'name': 'Madrid',
#     'timeZone': 'Europe/Madrid'},
#    'scheduledTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'revisedTime': {'utc': '2024-12-03 19:05Z',
#     'local': '2024-12-03 20:05+01:00'},
#    'terminal': '4',
#    'checkInDesk': '850-859',
#    'gate': 'K',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-03 22:10Z',
#     'local': '2024-12-03 23:10+01:00'},
#    'revisedTime': {'utc': '2024-12-03 22:10Z',
#     'local': '2024-12-03 23:10+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'I2 1809',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A320'},
#   'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#  {'departure': {'airport': {'icao': 'BIKF',
#     'iata': 'KEF',
#     'name': 'Reykjavik',
#     'timeZone': 'Atlantic/Reykjavik'},
#    'scheduledTime': {'utc': '2024-12-04 00:45Z',
#     'local': '2024-12-04 00:45+00:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 05:15Z',
#     'local': '2024-12-04 06:15+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'number': 'FI 518',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Boeing 737'},
#   'airline': {'name': 'Icelandair', 'iata': 'FI', 'icao': 'ICE'}},
#  {'departure': {'airport': {'icao': 'ZBAA',
#     'iata': 'PEK',
#     'name': 'Beijing',
#     'timeZone': 'Asia/Shanghai'},
#    'scheduledTime': {'utc': '2024-12-03 19:40Z',
#     'local': '2024-12-04 03:40+08:00'},
#    'revisedTime': {'utc': '2024-12-03 19:40Z',
#     'local': '2024-12-04 03:40+08:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 05:40Z',
#     'local': '2024-12-04 06:40+01:00'},
#    'revisedTime': {'utc': '2024-12-04 05:40Z',
#     'local': '2024-12-04 06:40+01:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'HU 489',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Boeing 787-9'},
#   'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#  {'departure': {'airport': {'icao': 'OTHH',
#     'iata': 'DOH',
#     'name': 'Doha',
#     'timeZone': 'Asia/Qatar'},
#    'scheduledTime': {'utc': '2024-12-03 23:40Z',
#     'local': '2024-12-04 02:40+03:00'},
#    'revisedTime': {'utc': '2024-12-03 23:40Z',
#     'local': '2024-12-04 02:40+03:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 05:55Z',
#     'local': '2024-12-04 06:55+01:00'},
#    'revisedTime': {'utc': '2024-12-04 05:55Z',
#     'local': '2024-12-04 06:55+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'QR 79',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Boeing 787-9'},
#   'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-04 05:20Z',
#     'local': '2024-12-04 06:20+01:00'},
#    'revisedTime': {'utc': '2024-12-04 05:20Z',
#     'local': '2024-12-04 06:20+01:00'},
#    'terminal': '3',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 06:35Z',
#     'local': '2024-12-04 07:35+01:00'},
#    'revisedTime': {'utc': '2024-12-04 06:35Z',
#     'local': '2024-12-04 07:35+01:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8001',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-04 05:30Z',
#     'local': '2024-12-04 06:30+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 06:40Z',
#     'local': '2024-12-04 07:40+01:00'},
#    'revisedTime': {'utc': '2024-12-04 06:40Z',
#     'local': '2024-12-04 07:40+01:00'},
#    'terminal': '1',
#    'gate': 'A06',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-04 05:15Z',
#     'local': '2024-12-04 06:15+01:00'},
#    'revisedTime': {'utc': '2024-12-04 05:15Z',
#     'local': '2024-12-04 06:15+01:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 06:45Z',
#     'local': '2024-12-04 07:45+01:00'},
#    'revisedTime': {'utc': '2024-12-04 06:45Z',
#     'local': '2024-12-04 07:45+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DS 1185',
#   'status': 'Expected',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-AYN', 'modeS': '4B027D', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-12-04 05:15Z',
#     'local': '2024-12-04 06:15+01:00'},
#    'revisedTime': {'utc': '2024-12-04 05:15Z',
#     'local': '2024-12-04 06:15+01:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 06:45Z',
#     'local': '2024-12-04 07:45+01:00'},
#    'revisedTime': {'utc': '2024-12-04 06:45Z',
#     'local': '2024-12-04 07:45+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 1185',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-AYN', 'modeS': '4B027D', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'KEWR',
#     'iata': 'EWR',
#     'name': 'Newark',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-12-03 22:50Z',
#     'local': '2024-12-03 17:50-05:00'},
#    'terminal': 'C',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 06:55Z',
#     'local': '2024-12-04 07:55+01:00'},
#    'revisedTime': {'utc': '2024-12-04 06:55Z',
#     'local': '2024-12-04 07:55+01:00'},
#    'terminal': '1',
#    'gate': 'Y17',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'UA 962',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'model': 'Boeing 767-400(ER)'},
#   'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-12-04 05:45Z',
#     'local': '2024-12-04 06:45+01:00'},
#    'revisedTime': {'utc': '2024-12-04 05:45Z',
#     'local': '2024-12-04 06:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-12-04 06:55Z',
#     'local': '2024-12-04 07:55+01:00'},
#    'revisedTime': {'utc': '2024-12-04 06:55Z',
#     'local': '2024-12-04 07:55+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 170',
#   'status': 'Expected',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIWK', 'modeS': '3C66EB', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}]

# %%
len(flight["arrivals"])
# Out:
# 68

# %%
flight["arrivals"][0]['departure']
# Out:
# {'airport': {'icao': 'EDDK',
#   'iata': 'CGN',
#   'name': 'Cologne',
#   'timeZone': 'Europe/Berlin'},
#  'scheduledTime': {'utc': '2024-12-03 17:50Z',
#   'local': '2024-12-03 18:50+01:00'},
#  'terminal': '1',
#  'quality': ['Basic']}

# %%
#Departure_airport_icao
flight["arrivals"][0]['departure']['airport']
# Out:
# {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne', 'timeZone': 'Europe/Berlin'}

# %%
flight["arrivals"][0]['departure']['scheduledTime']
# Out:
# {'utc': '2024-12-03 17:50Z', 'local': '2024-12-03 18:50+01:00'}

# %%
# Arrival_time
flight["arrivals"][0]['arrival']['revisedTime']
# Out:
# {'utc': '2024-12-03 19:00Z', 'local': '2024-12-03 20:00+01:00'}

# %%
# Flight_number
flight["arrivals"][0]['number']
# Out:
# 'EW 14'

# %%
#Arrival_airport_icao
Arrival_airport_icao = flight["arrivals"][0]["airline"].get("icao")
Arrival_airport_icao
# Out:
# 'EWG'

# %%
print(datetime.now().date())
# Out:
# 2024-12-03

# %%
def get_timezone_by_icao(icao_code):
    try:
        url = f"https://aerodatabox.p.rapidapi.com/airports/icao/{icao_code}"
        
        headers = {
            "x-rapidapi-key": safe_key["x_rapidapi_key"],
            "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
        }

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            timezone_str = data["timeZone"]  # Default to UTC if not found
            return timezone_str
        else:
            print(f"Failed to fetch timezone for ICAO: {icao_code}")
            return "UTC"
    except Exception as e:
        print(f"Error in timezone lookup for ICAO: {icao_code}: {e}")
        return "UTC"
    
icao_code = "VAPO"
timezone_str = get_timezone_by_icao(icao_code) or "UTC"
city_timezone = timezone(timezone_str)
today = datetime.now(city_timezone).date()
tomorrow = (today + timedelta(days=1))

print(today)
print(tomorrow)
# Out:
# 2024-12-03
# 2024-12-04

# %%
def FlightData_1(icao_code):

    flight_data = []

    for code in icao_code:

        # Find the city timezone based on icao code API
        timezone_str = get_timezone_by_icao(code) or "UTC"
        city_timezone = timezone(timezone_str)
        #get today date
        today = datetime.now(city_timezone).date()
        #get tommorrow date
        tomorrow = (today + timedelta(days=1))


        # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
        # using the nested lists below we can make a morning call and extract the data
        # then make an afternoon call and extract the data
        times = [["00:00","11:59"],
                ["12:00","23:59"]]

        for time in times:

            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{code}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {
                            "withLeg":"true",
                            "direction":"Arrival",
                            "withCancelled":"false",
                            "withCodeshared":"true",
                            "withCargo":"false",
                            "withPrivate":"false"
                        }

            headers = {
                "x-rapidapi-key": safe_key["x_rapidapi_key"],
                "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
                }

            response = requests.get(url, headers=headers, params=querystring)

            flight = response.json()

            retrieval_time = datetime.now(city_timezone).strftime("%Y-%m-%d %H:%M:%S")

        
        
            for item in flight["arrivals"]:
                data = {
                    "Arrival_airport_icao" : code,
                    "Departure_airport_icao" : item["departure"]["airport"].get("icao", None),
                    "Flight_number" : item.get("number", None),
                    "Arrival_time" : item["arrival"]["scheduledTime"].get("local", None),
                    "Data_retrieved_time": retrieval_time
                    }
                
                flight_data.append(data)
    
    flight_df = pd.DataFrame(flight_data)
    flight_df["Arrival_time"] = flight_df["Arrival_time"].str[:-6]
    flight_df["Arrival_time"] = pd.to_datetime(flight_df["Arrival_time"])
    flight_df["Data_retrieved_time"] = pd.to_datetime(flight_df["Data_retrieved_time"])
    
    return flight_df

icao_code = ["EDDB", "EDDF"]
FlightData_1(icao_code)
# Out:
#      Arrival_airport_icao Departure_airport_icao Flight_number  \
# 0                    EDDB                   BIKF        FI 518
# 1                    EDDB                   ZBAA        HU 489
# 2                    EDDB                   OTHH         QR 79
# 3                    EDDB                   EDDS       EW 8001
# 4                    EDDB                   EDDK          EW 2
# ...                   ...                    ...           ...
# 2169                 EDDF                   LPPT       LH 6957
# 2170                 EDDF                   LPPT       AC 2660
# 2171                 EDDF                   LPPT        TP 574
# 2172                 EDDF                   LPPT       S4 8762
# 2173                 EDDF                   GCRR       X3 2187
#
#             Arrival_time Data_retrieved_time
# 0    2024-12-04 06:15:00 2024-12-03 16:51:01
# 1    2024-12-04 06:40:00 2024-12-03 16:51:01
# 2    2024-12-04 06:55:00 2024-12-03 16:51:01
# 3    2024-12-04 07:35:00 2024-12-03 16:51:01
# 4    2024-12-04 07:40:00 2024-12-03 16:51:01
# ...                  ...                 ...
# 2169 2024-12-04 22:40:00 2024-12-03 16:51:05
# 2170 2024-12-04 22:40:00 2024-12-03 16:51:05
# 2171 2024-12-04 22:40:00 2024-12-03 16:51:05
# 2172 2024-12-04 22:40:00 2024-12-03 16:51:05
# 2173 2024-12-04 22:45:00 2024-12-03 16:51:05
#
# [2174 rows x 5 columns]

# %%
def FlightData(icao_airport_names_df):
    flight_data = []

    for code_row in icao_airport_names_df.itertuples(index=False):
        code = code_row.icao

        # Find the city timezone based on icao code API
        timezone_str = get_timezone_by_icao(code) or "UTC"
        city_timezone = timezone(timezone_str)

        # Get today and tomorrow's dates
        today = datetime.now(city_timezone).date()
        tomorrow = today + timedelta(days=1)

        # API requires two 12-hour calls
        times = [["00:00", "11:59"], ["12:00", "23:59"]]

        for time in times:
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{code}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"
            querystring = {
                "withLeg": "true",
                "direction": "Arrival",
                "withCancelled": "false",
                "withCodeshared": "true",
                "withCargo": "false",
                "withPrivate": "false"
            }
            headers = {
                "x-rapidapi-key": safe_key["x_rapidapi_key"],
                "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
            }

            # API request
            response = requests.get(url, headers=headers, params=querystring)
            
            if response.status_code != 200:
                print(f"Error fetching data for ICAO: {code}, Status Code: {response.status_code}")
                continue

            try:
                flight = response.json()
            except requests.exceptions.JSONDecodeError:
                print(f"Invalid JSON response for ICAO: {code}")
                continue

            # Data retrieval timestamp
            retrieval_time = datetime.now(city_timezone).strftime("%Y-%m-%d %H:%M:%S")

            # Parse arrivals
            for item in flight.get("arrivals", []):
                arrival_time = item["arrival"]["scheduledTime"].get("local", None)
                if not arrival_time:
                    continue

                data = {
                    "Arrival_airport_icao": code,
                    "Departure_airport_icao": item["departure"]["airport"].get("icao", None),
                    "Flight_number": item.get("number", None),
                    "Arrival_time": arrival_time,
                    "Data_retrieved_time": retrieval_time
                }
                flight_data.append(data)

    # Create DataFrame
    flight_df = pd.DataFrame(flight_data)
    if not flight_df.empty:
        flight_df["Arrival_time"] = pd.to_datetime(flight_df["Arrival_time"].str[:-6])
        flight_df["Data_retrieved_time"] = pd.to_datetime(flight_df["Data_retrieved_time"])
    return flight_df

# Example usage
#icao_airport_codes_df = pd.DataFrame({"icao": ["EDDB", "EDDF"]})
FlightData(icao_airport_names_df)
# Out:
# Error fetching data for ICAO: LFPB, Status Code: 204
# Error fetching data for ICAO: LFPB, Status Code: 204
#      Arrival_airport_icao Departure_airport_icao Flight_number  \
# 0                    EDDB                   BIKF        FI 518
# 1                    EDDB                   ZBAA        HU 489
# 2                    EDDB                   OTHH         QR 79
# 3                    EDDB                   EDDS       EW 8001
# 4                    EDDB                   EDDK          EW 2
# ...                   ...                    ...           ...
# 1088                 VAPO                   VIDP       6E 5342
# 1089                 VAPO                   VIJP       6E 6116
# 1090                 VAPO                   VILK        6E 118
# 1091                 VAPO                   VECC        6E 476
# 1092                 VAPO                   VIDP       IX 1176
#
#             Arrival_time Data_retrieved_time
# 0    2024-12-04 06:15:00 2024-12-03 17:11:12
# 1    2024-12-04 06:40:00 2024-12-03 17:11:12
# 2    2024-12-04 06:55:00 2024-12-03 17:11:12
# 3    2024-12-04 07:35:00 2024-12-03 17:11:12
# 4    2024-12-04 07:40:00 2024-12-03 17:11:12
# ...                  ...                 ...
# 1088 2024-12-04 23:15:00 2024-12-03 21:41:26
# 1089 2024-12-04 23:20:00 2024-12-03 21:41:26
# 1090 2024-12-04 23:30:00 2024-12-03 21:41:26
# 1091 2024-12-04 23:35:00 2024-12-03 21:41:26
# 1092 2024-12-04 23:50:00 2024-12-03 21:41:26
#
# [1093 rows x 5 columns]
